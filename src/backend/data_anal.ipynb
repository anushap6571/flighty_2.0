# %%
import pandas as pd


to_remove = ["\\N", ""]
df = pd.read_csv('airline_codes.csv')
df.columns = ['index', 'airline_name', 'alias', 'IATA', 'ICAO', 'callsign', 'country', 'active']
df = df[df['active'] == 'Y']

airline_names = df['airline_name']
airline_names = airline_names.to_list()

airline_names = set(airline_names)

print(len(airline_names), airline_names)
# Out:
# 1247 {'Tiara Air', 'Emirates', 'Kenya Airways', 'Icelandair', 'Alrosa Mirny Air Enterprise', 'Europe Jet', 'SENIC AIRLINES', 'Rwandair Express', 'SriLankan Airlines', 'Air Berlin', 'ATRAN Cargo Airlines', 'EgyptAir Express', 'LAN Peru', 'International AirLink', 'Royal Nepal Airlines', 'Kenmore Air', 'Polet', 'Royal Airways', 'North American Airlines', 'US-Bangla Airlines', 'Ciel Canadien', 'Windward Islands Airways', 'PEGASUS AIRLINES-', 'Myanmar Airways International', "Salsa d\\\\'Haiti", 'Aircompany Yakutia', 'Xiamen Airlines', 'Rainbow Air Polynesia', 'Qatar Airways', 'WestJet Encore', 'Hapagfly', 'Allegheny Commuter Airlines', 'FOX Linhas Aereas', 'FlyEgypt', 'Air Foyle', 'Surinam Airways', 'MHS Aviation GmbH', 'University of Birmingham Air Squadron (RAF)', 'Harbour Air (Priv)', 'Thai Airways International', 'Syrian Arab Airlines', 'Cape Air', 'All Argentina Express', 'Air India Express', 'Baikotovitchestrian Airlines ', 'GermanXL', 'Bluebird Airways (BZ)', 'Air Madagascar', 'Southjet connect', 'West Coast Air', 'Thomas Cook Airlines', 'Wizz Air', 'Air Nippon', 'Passaredo Transportes Aereos', 'CanXpress', 'Adam Air', 'Dobrolet', 'Blue Air', 'Mauritania Airways', 'Sun Country Airlines', 'Trans Pas Air', 'Japan Airlines Domestic', 'Skynet Airlines', 'Lufthansa Cargo', 'Itek Air', 'Congo Express', 'Wizz Air Ukraine', 'AtlasGlobal Ukraine', 'Ecuavia', 'America West Airlines', 'Joy Air', 'Pacific Coastal Airline', 'Westfalia Express VA', 'German Air Force - FLB', 'Cyprus Turkish Airlines', 'Air Namibia', 'All America CO', 'Nile Air', 'Islena De Inversiones', 'Maldivian Air Taxi', 'Orient Thai Airlines', 'Island Spirit', 'Air Choice One', 'Virginwings', 'Airlinair', 'Kush Air', 'Texas Wings', 'LSM International ', 'All America', 'Locair', 'Serbian Airlines', 'QatXpress', 'Japan Regio', 'Jayrow', 'Copterline', 'Eritrean Airlines', 'New England Airlines', 'Russia State Transport', 'Hi Fly (5K)', 'Pakistan International Airlines', 'Air Malawi', 'Malaysia Wings', 'bmi', 'KLM Royal Dutch Airlines', 'LTE International Airways', 'Atlasjet', 'LAN Argentina', 'TrasBrasil', 'Arik Niger', 'Shandong Airlines', 'Carnival Air Lines', 'AeroWorld ', 'Trigana Air Service', 'Zabaykalskii Airlines', 'Air VIA', 'Shenzhen Airlines', 'Air India Limited', 'Turan Air', 'Era Alaska', 'SATA International', 'Gulf Air Bahrain', 'Icar Air', 'Africa West', 'Ozjet Airlines', 'Onur Air', 'Air Philippines', 'Oman Air', 'Azul', 'Star1 Airlines', 'Jagson Airlines', 'Sriwijaya Air', 'Air Sinai', 'Air Century', 'Eagle Atlantic Airlines', 'LSM Airlines', 'Southern Airways', 'Vuola Italia', 'United Airlines', 'Air Batumi', 'Jusur airways', 'Nesma Airlines', 'China Eastern Airlines', 'Highland Airways', 'Air Serbia', 'Middle East Airlines', 'Southeast Air', 'Globus', 'Askari Aviation', 'VickJet', 'All Nippon Airways', 'Airlines PNG', 'Olympic Airlines', 'East Horizon', 'Aero Lanka', 'Air Cargo Carriers', 'Homer Air', 'Turkmenistan Airlines', 'Yemenia', 'Volga-Dnepr Airlines', 'Regional Airlines', 'Orbest', 'Russkie Krylya', 'Caribbean Airlines', 'Aserca Airlines', 'Frontier Airlines', 'XAIR USA', 'ATA Airlines', 'Turkish Airlines', 'Norfolk County Flight College', 'Dubrovnik Air', 'Island Air (WP)', 'Transavia Denmark', 'TUIfly (X3)', 'Southern Winds Airlines', 'Armavia', 'AD Aviation', 'Euro Exec Express', 'I-Fly', 'Alitalia', 'Tarom', 'FlyPortugal', 'Vision Airlines (V2)', 'Yeti Airways', 'VietJet Air', 'Jazeera Airways', 'Executive AirShare', 'Air Arabia Maroc', 'Air Guyane', 'Andalus Lineas Aereas', 'Air Mauritius', 'Jetstar Japan ', 'MAT Airways', 'Solomon Airlines', 'Eurowings', 'Air Comet Chile', 'N1', 'Republic Airlines', 'SUR Lineas Aereas', 'Air Tahiti', 'Transportes Aereos Cielos Andinos', 'Aruba Airlines', 'Japan Airlines', 'Orbit Regional Airlines', 'Yuzhmashavia', 'First Flying', 'Bateleur Air', 'TUIfly', 'Usa Sky Cargo', 'Singapore Airlines Cargo', 'Corse-Mediterranee', 'Binter Canarias', 'Indonesia Sky', 'Jettor Airlines', 'Air China', 'San Dima Air', ...
